# %% [markdown]
# <a href="https://colab.research.google.com/github/jyotidabass/Classification/blob/main/Color%20Space%20Conversions_tensforflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q tensorflow-io
# Out:
#      |████████████████████████████████| 23.4 MB 115.0 MB/s

# %% [markdown]
# Read Image File

# %%
import tensorflow as tf
import tensorflow_io as tfio

image = tf.image.decode_jpeg(tf.io.read_file('/Tongue Pic. - Gulshan Rai.jpg'))

print(image.shape, image.dtype)
# Out:
# (2488, 2039, 3) <dtype: 'uint8'>

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.imshow(image)
plt.axis('off')
plt.show()

# %% [markdown]
# Convert RGB to Grayscale

# %%
grayscale = tfio.experimental.color.rgb_to_grayscale(image)

print(grayscale.shape, grayscale.dtype)

# use tf.squeeze to remove last channel for plt.imshow to display:
plt.figure()
plt.imshow(tf.squeeze(grayscale, axis=-1), cmap='gray')
plt.axis('off')
plt.show()
# Out:
# (2488, 2039, 1) <dtype: 'uint8'>

# %% [markdown]
# Convert RGB to BGR

# %%
bgr = tfio.experimental.color.rgb_to_bgr(image)

print(bgr.shape, bgr.dtype)

plt.figure()
plt.imshow(bgr)
plt.axis('off')
plt.show()
# Out:
# (2488, 2039, 3) <dtype: 'uint8'>

# %% [markdown]
# Convert RGB to CIE XYZ

# %%
# convert to float32
image_float32 = tf.cast(image, tf.float32) / 255.0

xyz_float32 = tfio.experimental.color.rgb_to_xyz(image_float32)

# convert back uint8
xyz = tf.cast(xyz_float32 * 255.0, tf.uint8)

print(xyz.shape, xyz.dtype)

plt.figure()
plt.imshow(xyz)
plt.axis('off')
plt.show()
# Out:
# (2488, 2039, 3) <dtype: 'uint8'>

# %% [markdown]
# Convert RGB to YCbCr

# %%
ycbcr = tfio.experimental.color.rgb_to_ycbcr(image)

print(ycbcr.shape, ycbcr.dtype)

plt.figure()
plt.imshow(ycbcr, cmap='gray')
plt.axis('off')
plt.show()
# Out:
# (2488, 2039, 3) <dtype: 'uint8'>

# %%
y, cb, cr = ycbcr[:,:,0], ycbcr[:,:,1], ycbcr[:,:,2]

# Y' component
plt.figure()
plt.imshow(y, cmap='gray')
plt.axis('off')
plt.show()

# Cb component
plt.figure()
plt.imshow(cb, cmap='gray')
plt.axis('off')
plt.show()

# Cr component
plt.figure()
plt.imshow(cr, cmap='gray')
plt.axis('off')
plt.show()
